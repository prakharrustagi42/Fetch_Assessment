# %%
import pandas as pd 
import json

# %%
### Reading the three jsons and loading then into a dataframe

# File paths
file_paths = {
    'brands': 'brands.json',
    'receipts': 'receipts.json',
    'users': 'users.json'
}

# Function to read and parse JSON lines file
def read_json_file(file_path):
    data = []
    with open(file_path, 'r') as file:
        for line in file:
            line = line.strip()
            if line:  
                try:
                    json_object = json.loads(line)  
                    data.append(json_object)  
                except json.JSONDecodeError as e:
                    print(f"Error decoding JSON on line: {line} - Error: {e}")
    return data

# Reading each file and converting to DataFrame
brands_data = read_json_file(file_paths['brands'])
receipts_data = read_json_file(file_paths['receipts'])
users_data = read_json_file(file_paths['users'])

# Converting lists of JSON objects to DataFrames
brands = pd.DataFrame(brands_data)
receipts  = pd.DataFrame(receipts_data)
users = pd.DataFrame(users_data)

# %%
receipts.head()
# Out:
#                                     _id  bonusPointsEarned  \
# 0  {'$oid': '5ff1e1eb0a720f0523000575'}              500.0
# 1  {'$oid': '5ff1e1bb0a720f052300056b'}              150.0
# 2  {'$oid': '5ff1e1f10a720f052300057a'}                5.0
# 3  {'$oid': '5ff1e1ee0a7214ada100056f'}                5.0
# 4  {'$oid': '5ff1e1d20a7214ada1000561'}                5.0
#
#                              bonusPointsEarnedReason  \
# 0  Receipt number 2 completed, bonus point schedu...
# 1  Receipt number 5 completed, bonus point schedu...
# 2                         All-receipts receipt bonus
# 3                         All-receipts receipt bonus
# 4                         All-receipts receipt bonus
#
#                  createDate               dateScanned  \
# 0  {'$date': 1609687531000}  {'$date': 1609687531000}
# 1  {'$date': 1609687483000}  {'$date': 1609687483000}
# 2  {'$date': 1609687537000}  {'$date': 1609687537000}
# 3  {'$date': 1609687534000}  {'$date': 1609687534000}
# ...

# %%
##fixing the id column : extracting the values form dictionaries

receipts["_id"] = receipts["_id"].apply(lambda x : x["$oid"])

# %%
receipts.head()
# Out:
#                         _id  bonusPointsEarned  \
# 0  5ff1e1eb0a720f0523000575              500.0
# 1  5ff1e1bb0a720f052300056b              150.0
# 2  5ff1e1f10a720f052300057a                5.0
# 3  5ff1e1ee0a7214ada100056f                5.0
# 4  5ff1e1d20a7214ada1000561                5.0
#
#                              bonusPointsEarnedReason  \
# 0  Receipt number 2 completed, bonus point schedu...
# 1  Receipt number 5 completed, bonus point schedu...
# 2                         All-receipts receipt bonus
# 3                         All-receipts receipt bonus
# 4                         All-receipts receipt bonus
#
#                  createDate               dateScanned  \
# 0  {'$date': 1609687531000}  {'$date': 1609687531000}
# 1  {'$date': 1609687483000}  {'$date': 1609687483000}
# 2  {'$date': 1609687537000}  {'$date': 1609687537000}
# 3  {'$date': 1609687534000}  {'$date': 1609687534000}
# 4  {'$date': 1609687506000}  {'$date': 1609687506000}
#
# ...

# %%
'''
this function will fix the date and give unknown if there is no key 
'''

def date_format_fixer(x):
    
    try:
        return( pd.to_datetime(x["$date"], unit='ms'))
    except TypeError:
        return("unknown")

# %%
receipts["createDate"] =receipts["createDate"].apply(lambda x : date_format_fixer(x) )
receipts["dateScanned"] =receipts["dateScanned"].apply(lambda x : date_format_fixer(x) )
receipts["finishedDate"] =receipts["finishedDate"].apply(lambda x : date_format_fixer(x) )
receipts["modifyDate"] =receipts["modifyDate"].apply(lambda x : date_format_fixer(x) )
receipts["pointsAwardedDate"] =receipts["pointsAwardedDate"].apply(lambda x : date_format_fixer(x) )
receipts["purchaseDate"] =receipts["purchaseDate"].apply(lambda x : date_format_fixer(x) )

# %%
receipts.head()
# Out:
#                         _id  bonusPointsEarned  \
# 0  5ff1e1eb0a720f0523000575              500.0
# 1  5ff1e1bb0a720f052300056b              150.0
# 2  5ff1e1f10a720f052300057a                5.0
# 3  5ff1e1ee0a7214ada100056f                5.0
# 4  5ff1e1d20a7214ada1000561                5.0
#
#                              bonusPointsEarnedReason          createDate  \
# 0  Receipt number 2 completed, bonus point schedu... 2021-01-03 15:25:31
# 1  Receipt number 5 completed, bonus point schedu... 2021-01-03 15:24:43
# 2                         All-receipts receipt bonus 2021-01-03 15:25:37
# 3                         All-receipts receipt bonus 2021-01-03 15:25:34
# 4                         All-receipts receipt bonus 2021-01-03 15:25:06
#
#           dateScanned         finishedDate          modifyDate  \
# 0 2021-01-03 15:25:31  2021-01-03 15:25:31 2021-01-03 15:25:36
# 1 2021-01-03 15:24:43  2021-01-03 15:24:43 2021-01-03 15:24:48
# ...

# %% [markdown]
# #### Separating the Outer RewardsReceiptItemList into a table and taking receipt number for reference

# %%
all_items = []

# Iterate over 'rewardsReceiptItemList'

for index, itemList in receipts['rewardsReceiptItemList'].dropna().items():
    receipt_id = receipts.loc[index, '_id']  # Get the corresponding receipt ID
    
    # Check if itemList is indeed a list before iterating
    if isinstance(itemList, list):
        for item in itemList:
            if isinstance(item, dict):  # Ensure each item is a dictionary
                item['oid'] = receipt_id  # Assign receipt ID to each item
                all_items.append(item)  # Append the modified item to the list
    else:
        print(f"Warning: Skipping non-list entry at index {index}")

# Create a DataFrame from the list of all items
rewarditemlist = pd.DataFrame(all_items)

# %%
rewarditemlist.head()
# Out:
#         barcode                                        description finalPrice  \
# 0          4011                                     ITEM NOT FOUND      26.00
# 1          4011                                     ITEM NOT FOUND          1
# 2  028400642255  DORITOS TORTILLA CHIP SPICY SWEET CHILI REDUCE...      10.00
# 3           NaN                                                NaN        NaN
# 4          4011                                     ITEM NOT FOUND      28.00
#
#   itemPrice needsFetchReview partnerItemId preventTargetGapPoints  \
# 0     26.00            False             1                   True
# 1         1              NaN             1                    NaN
# 2     10.00             True             2                   True
# 3       NaN            False             1                   True
# 4     28.00            False             1                   True
#
#    quantityPurchased userFlaggedBarcode userFlaggedNewItem  ... itemNumber  \
# ...

# %%
receipts = receipts.drop(columns = ["rewardsReceiptItemList"],axis = 1)

# %%
receipts.head()
# Out:
#                         _id  bonusPointsEarned  \
# 0  5ff1e1eb0a720f0523000575              500.0
# 1  5ff1e1bb0a720f052300056b              150.0
# 2  5ff1e1f10a720f052300057a                5.0
# 3  5ff1e1ee0a7214ada100056f                5.0
# 4  5ff1e1d20a7214ada1000561                5.0
#
#                              bonusPointsEarnedReason          createDate  \
# 0  Receipt number 2 completed, bonus point schedu... 2021-01-03 15:25:31
# 1  Receipt number 5 completed, bonus point schedu... 2021-01-03 15:24:43
# 2                         All-receipts receipt bonus 2021-01-03 15:25:37
# 3                         All-receipts receipt bonus 2021-01-03 15:25:34
# 4                         All-receipts receipt bonus 2021-01-03 15:25:06
#
#           dateScanned         finishedDate          modifyDate  \
# 0 2021-01-03 15:25:31  2021-01-03 15:25:31 2021-01-03 15:25:36
# 1 2021-01-03 15:24:43  2021-01-03 15:24:43 2021-01-03 15:24:48
# ...

# %% [markdown]
# #### Now Brands

# %%
brands.head()
# Out:
#                                     _id       barcode        category  \
# 0  {'$oid': '601ac115be37ce2ead437551'}  511111019862          Baking
# 1  {'$oid': '601c5460be37ce2ead43755f'}  511111519928       Beverages
# 2  {'$oid': '601ac142be37ce2ead43755d'}  511111819905          Baking
# 3  {'$oid': '601ac142be37ce2ead43755a'}  511111519874          Baking
# 4  {'$oid': '601ac142be37ce2ead43755e'}  511111319917  Candy & Sweets
#
#        categoryCode                                                cpg  \
# 0            BAKING  {'$id': {'$oid': '601ac114be37ce2ead437550'}, ...
# 1         BEVERAGES  {'$id': {'$oid': '5332f5fbe4b03c9a25efd0ba'}, ...
# 2            BAKING  {'$id': {'$oid': '601ac142be37ce2ead437559'}, ...
# 3            BAKING  {'$id': {'$oid': '601ac142be37ce2ead437559'}, ...
# 4  CANDY_AND_SWEETS  {'$id': {'$oid': '5332fa12e4b03c9a25efd1e7'}, ...
#
#                         name topBrand                      brandCode
# ...

# %%
## we can use json normalize as there are more than one field in the dictionary

brands_norm = pd.json_normalize(brands['cpg'])

# %%
brands_norm.head(10)
# Out:
#    $ref                  $id.$oid
# 0  Cogs  601ac114be37ce2ead437550
# 1  Cogs  5332f5fbe4b03c9a25efd0ba
# 2  Cogs  601ac142be37ce2ead437559
# 3  Cogs  601ac142be37ce2ead437559
# 4  Cogs  5332fa12e4b03c9a25efd1e7
# 5  Cogs  601ac142be37ce2ead437559
# 6  Cogs  601ac142be37ce2ead437559
# 7  Cogs  559c2234e4b06aca36af13c6
# 8  Cogs  5a734034e4b0d58f376be874
# 9  Cogs  59ba6f1ce4b092b29c167346

# %%
brands_norm = brands_norm.add_prefix('cpg.')

# %%
brands_norm
# Out:
#      cpg.$ref              cpg.$id.$oid
# 0        Cogs  601ac114be37ce2ead437550
# 1        Cogs  5332f5fbe4b03c9a25efd0ba
# 2        Cogs  601ac142be37ce2ead437559
# 3        Cogs  601ac142be37ce2ead437559
# 4        Cogs  5332fa12e4b03c9a25efd1e7
# ...       ...                       ...
# 1162     Cogs  5f77274dbe37ce6b592e90bf
# 1163     Cogs  53e10d6368abd3c7065097cc
# 1164     Cogs  5332fa12e4b03c9a25efd1e7
# 1165     Cogs  5332f5f6e4b03c9a25efd0b4
# 1166     Cogs  6026d757be37ce6369301467
#
# [1167 rows x 2 columns]

# %%
brands_final = pd.merge(brands, brands_norm, left_index=True, right_index=True, how='outer')

# %%
brands_final.head()
# Out:
#                                     _id       barcode        category  \
# 0  {'$oid': '601ac115be37ce2ead437551'}  511111019862          Baking
# 1  {'$oid': '601c5460be37ce2ead43755f'}  511111519928       Beverages
# 2  {'$oid': '601ac142be37ce2ead43755d'}  511111819905          Baking
# 3  {'$oid': '601ac142be37ce2ead43755a'}  511111519874          Baking
# 4  {'$oid': '601ac142be37ce2ead43755e'}  511111319917  Candy & Sweets
#
#        categoryCode                                                cpg  \
# 0            BAKING  {'$id': {'$oid': '601ac114be37ce2ead437550'}, ...
# 1         BEVERAGES  {'$id': {'$oid': '5332f5fbe4b03c9a25efd0ba'}, ...
# 2            BAKING  {'$id': {'$oid': '601ac142be37ce2ead437559'}, ...
# 3            BAKING  {'$id': {'$oid': '601ac142be37ce2ead437559'}, ...
# 4  CANDY_AND_SWEETS  {'$id': {'$oid': '5332fa12e4b03c9a25efd1e7'}, ...
#
#                         name topBrand                      brandCode cpg.$ref  \
# ...

# %%
## to fix the id column

brands_final['_id'] = brands_final['_id'].apply(lambda x: x['$oid'])

# %%
brands_final.head()
# Out:
#                         _id       barcode        category      categoryCode  \
# 0  601ac115be37ce2ead437551  511111019862          Baking            BAKING
# 1  601c5460be37ce2ead43755f  511111519928       Beverages         BEVERAGES
# 2  601ac142be37ce2ead43755d  511111819905          Baking            BAKING
# 3  601ac142be37ce2ead43755a  511111519874          Baking            BAKING
# 4  601ac142be37ce2ead43755e  511111319917  Candy & Sweets  CANDY_AND_SWEETS
#
#                                                  cpg  \
# 0  {'$id': {'$oid': '601ac114be37ce2ead437550'}, ...
# 1  {'$id': {'$oid': '5332f5fbe4b03c9a25efd0ba'}, ...
# 2  {'$id': {'$oid': '601ac142be37ce2ead437559'}, ...
# 3  {'$id': {'$oid': '601ac142be37ce2ead437559'}, ...
# 4  {'$id': {'$oid': '5332fa12e4b03c9a25efd1e7'}, ...
#
#                         name topBrand                      brandCode cpg.$ref  \
# 0  test brand @1612366101024    False                            NaN     Cogs
# ...

# %% [markdown]
# ### finallly the user table

# %%
users.head()
# Out:
#                                     _id  active               createdDate  \
# 0  {'$oid': '5ff1e194b6a9d73a3a9f1052'}    True  {'$date': 1609687444800}
# 1  {'$oid': '5ff1e194b6a9d73a3a9f1052'}    True  {'$date': 1609687444800}
# 2  {'$oid': '5ff1e194b6a9d73a3a9f1052'}    True  {'$date': 1609687444800}
# 3  {'$oid': '5ff1e1eacfcf6c399c274ae6'}    True  {'$date': 1609687530554}
# 4  {'$oid': '5ff1e194b6a9d73a3a9f1052'}    True  {'$date': 1609687444800}
#
#                   lastLogin      role signUpSource state
# 0  {'$date': 1609687537858}  consumer        Email    WI
# 1  {'$date': 1609687537858}  consumer        Email    WI
# 2  {'$date': 1609687537858}  consumer        Email    WI
# 3  {'$date': 1609687530597}  consumer        Email    WI
# 4  {'$date': 1609687537858}  consumer        Email    WI

# %%
## for the id column

users['_id'] = users['_id'].apply(lambda x: x['$oid'])

# %%
## fixing the date columns using the same function

users['createdDate'] = users['createdDate'].apply(lambda x: date_format_fixer(x))
users['lastLogin'] = users['lastLogin'].apply(lambda x: date_format_fixer(x))

# %%
users.head()
# Out:
#                         _id  active             createdDate  \
# 0  5ff1e194b6a9d73a3a9f1052    True 2021-01-03 15:24:04.800
# 1  5ff1e194b6a9d73a3a9f1052    True 2021-01-03 15:24:04.800
# 2  5ff1e194b6a9d73a3a9f1052    True 2021-01-03 15:24:04.800
# 3  5ff1e1eacfcf6c399c274ae6    True 2021-01-03 15:25:30.554
# 4  5ff1e194b6a9d73a3a9f1052    True 2021-01-03 15:24:04.800
#
#                     lastLogin      role signUpSource state
# 0  2021-01-03 15:25:37.858000  consumer        Email    WI
# 1  2021-01-03 15:25:37.858000  consumer        Email    WI
# 2  2021-01-03 15:25:37.858000  consumer        Email    WI
# 3  2021-01-03 15:25:30.597000  consumer        Email    WI
# 4  2021-01-03 15:25:37.858000  consumer        Email    WI

# %% [markdown]
# # exporting and csv's

# %%
### for ease of export to mysql workbench ( it drops the record where numerical column values are null so taking 0 )

receipts['bonusPointsEarned'] = receipts['bonusPointsEarned'].fillna(0.00)
receipts['pointsEarned'] = receipts['pointsEarned'].fillna(0.00)
receipts['purchasedItemCount'] = receipts['purchasedItemCount'].fillna(0.00)
receipts['totalSpent'] = receipts['totalSpent'].fillna(0.00)


rewarditemlist["quantityPurchased"] = rewarditemlist["quantityPurchased"].fillna(0.00)

# %%
## coverting dataframes to csv for further sql querying 

# brands_final.to_csv("brands_final.csv")
# receipts.to_csv("receipts_final.csv")
# users.to_csv("users.csv")
# rewarditemlist.to_csv("rewarditemlist.csv")

# %% [markdown]
# ## Data Quality Issues

# %% [markdown]
# Reason for a weak join between Receipts and Brands :
# Mismatch of Brandcodes in both tables i.e. Some brandcodes present in brands but missing in Receipts is not an issue, but brands present in receipts and missing in brands table is a data quality issue.

# %%
brands_final["brandCode"].nunique()                    ## number of unique brands in brands tables including nulls
# Out:
# 897

# %%
rewarditemlist["brandCode"].nunique()     ## number of unique brands in receipts table
# Out:
# 227

# %%
receipts_brandcode = rewarditemlist["brandCode"].unique()
brands_brandcode = brands_final['brandCode'].unique()

# %%
exists_in_brands = pd.Series(receipts_brandcode).isin(brands_brandcode)

# %%
rewarditemlist["brandCode"].nunique() - exists_in_brands.sum()
# Out:
# 185

# %% [markdown]
# #### 185 brands( out of 227) in Receipt table are missing in Brands table ( therefore barcode and brandcode joins will have a lot of data quality issues)

# %% [markdown]
# ### Duplications in Users

# %%
users.head()
# Out:
#                         _id  active             createdDate  \
# 0  5ff1e194b6a9d73a3a9f1052    True 2021-01-03 15:24:04.800
# 1  5ff1e194b6a9d73a3a9f1052    True 2021-01-03 15:24:04.800
# 2  5ff1e194b6a9d73a3a9f1052    True 2021-01-03 15:24:04.800
# 3  5ff1e1eacfcf6c399c274ae6    True 2021-01-03 15:25:30.554
# 4  5ff1e194b6a9d73a3a9f1052    True 2021-01-03 15:24:04.800
#
#                     lastLogin      role signUpSource state
# 0  2021-01-03 15:25:37.858000  consumer        Email    WI
# 1  2021-01-03 15:25:37.858000  consumer        Email    WI
# 2  2021-01-03 15:25:37.858000  consumer        Email    WI
# 3  2021-01-03 15:25:30.597000  consumer        Email    WI
# 4  2021-01-03 15:25:37.858000  consumer        Email    WI

# %%
users.shape
# Out:
# (495, 7)

# %%
users["_id"].nunique()
# Out:
# 212

# %% [markdown]
# #### WE have only 212 unique user ids

# %%
users[users["_id"] == "54943462e4b07e684157a532"].reset_index()  ### example to show duplicates
# Out:
#     index                       _id  active             createdDate  \
# 0     475  54943462e4b07e684157a532    True 2014-12-19 14:21:22.381
# 1     476  54943462e4b07e684157a532    True 2014-12-19 14:21:22.381
# 2     477  54943462e4b07e684157a532    True 2014-12-19 14:21:22.381
# 3     478  54943462e4b07e684157a532    True 2014-12-19 14:21:22.381
# 4     479  54943462e4b07e684157a532    True 2014-12-19 14:21:22.381
# 5     480  54943462e4b07e684157a532    True 2014-12-19 14:21:22.381
# 6     481  54943462e4b07e684157a532    True 2014-12-19 14:21:22.381
# 7     482  54943462e4b07e684157a532    True 2014-12-19 14:21:22.381
# 8     483  54943462e4b07e684157a532    True 2014-12-19 14:21:22.381
# 9     484  54943462e4b07e684157a532    True 2014-12-19 14:21:22.381
# 10    485  54943462e4b07e684157a532    True 2014-12-19 14:21:22.381
# 11    486  54943462e4b07e684157a532    True 2014-12-19 14:21:22.381
# 12    487  54943462e4b07e684157a532    True 2014-12-19 14:21:22.381
# ...

# %%
brands_final.head()
# Out:
#                         _id       barcode        category      categoryCode  \
# 0  601ac115be37ce2ead437551  511111019862          Baking            BAKING
# 1  601c5460be37ce2ead43755f  511111519928       Beverages         BEVERAGES
# 2  601ac142be37ce2ead43755d  511111819905          Baking            BAKING
# 3  601ac142be37ce2ead43755a  511111519874          Baking            BAKING
# 4  601ac142be37ce2ead43755e  511111319917  Candy & Sweets  CANDY_AND_SWEETS
#
#                                                  cpg  \
# 0  {'$id': {'$oid': '601ac114be37ce2ead437550'}, ...
# 1  {'$id': {'$oid': '5332f5fbe4b03c9a25efd0ba'}, ...
# 2  {'$id': {'$oid': '601ac142be37ce2ead437559'}, ...
# 3  {'$id': {'$oid': '601ac142be37ce2ead437559'}, ...
# 4  {'$id': {'$oid': '5332fa12e4b03c9a25efd1e7'}, ...
#
#                         name topBrand                      brandCode cpg.$ref  \
# 0  test brand @1612366101024    False                            NaN     Cogs
# ...

# %%
brands_final.shape
# Out:
# (1167, 10)

# %%
brands_final["_id"].nunique() ## looks fine
# Out:
# 1167
